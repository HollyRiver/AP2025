# %% [markdown]
# `-` 제안 주제
#
# 1. 베이지안 예측 (MC dropout)
# > Classification, Regression, Segmentation 등등에서 베이지안을 이용한 예측이 어느 정도의 성능을 가지는 지 연구. 성능 향상의 문제
# 2. Uncertanty Measure (MC dropout으로 인한 Interval)
# > 손계산?
# 3. 자유주제 "정말 이걸 하고 싶다.", "이 문제를 풀고 싶다." 에바
#
# * 베이지안 예측이 가장 무난하고 쉽지 않을까
